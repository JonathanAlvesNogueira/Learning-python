# %%
import pandas as pd
import numpy as np

# %%
url = 'D:/credito.csv'
dt = pd.read_csv(url)
display(dt)
# Out:
#               id  default  idade sexo  dependentes         escolaridade  \
# 0      768805383        0     45    M            3         ensino medio
# 1      818770008        0     49    F            5             mestrado
# 2      713982108        0     51    M            3             mestrado
# 3      769911858        0     40    F            4         ensino medio
# 4      709106358        0     40    M            3  sem educacao formal
# ...          ...      ...    ...  ...          ...                  ...
# 10122  772366833        0     50    M            2             mestrado
# 10123  710638233        1     41    M            2                   na
# 10124  716506083        1     44    F            1         ensino medio
# 10125  717406983        1     30    M            2             mestrado
# 10126  714337233        1     43    F            2             mestrado
#
#       estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# ...

# %%
dt2 = dt[dt['idade'] > 30].copy()

display(dt2)
# Out:
#               id  default  idade sexo  dependentes         escolaridade  \
# 0      768805383        0     45    M            3         ensino medio
# 1      818770008        0     49    F            5             mestrado
# 2      713982108        0     51    M            3             mestrado
# 3      769911858        0     40    F            4         ensino medio
# 4      709106358        0     40    M            3  sem educacao formal
# ...          ...      ...    ...  ...          ...                  ...
# 10121  713899383        0     56    F            1             mestrado
# 10122  772366833        0     50    M            2             mestrado
# 10123  710638233        1     41    M            2                   na
# 10124  716506083        1     44    F            1         ensino medio
# 10126  714337233        1     43    F            2             mestrado
#
#       estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# ...

# %%
dt2['fx_sexo'] = np.where(dt2['sexo'] == 'M', 'Masculino' ,'Feminino') 
dt4 = dt2.copy()
dt3 = dt2.copy()
cubo = dt3.groupby('escolaridade').agg(QTD=('escolaridade', 'size')
                                ,SOMA_PRODUTOS=('qtd_produtos', 'sum')
                                )

conditions = [
    (dt4['dependentes'] >= 5 , 'A) >= 5')
    ,(dt4['dependentes'] > 3, 'B) 3-4' )
    ,(dt4['dependentes'] <= 3 , 'C) 1-3')
]

choices = ['A) >= 5', 'B) 3-4', 'C) 1-3']

dt4['fx_dependen'] = np.select(conditions, choices, default='outros')



display(dt4.head(10))


# display(cubo[cubo['QTD'] > 1000])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 16
#       8 conditions = [
#       9     (dt4['dependentes'] >= 5 , 'A) >= 5')
#      10     ,(dt4['dependentes'] > 3, 'B) 3-4' )
#      11     ,(dt4['dependentes'] <= 3 , 'C) 1-3')
#      12 ]
#      14 choices = ['A) >= 5', 'B) 3-4', 'C) 1-3']
# ---> 16 dt4['fx_dependen'] = np.select(conditions, choices, default='outros')
#      20 display(dt4.head(10))
#      23 # display(cubo[cubo['QTD'] > 1000])
#
# File c:\Users\joth1\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\function_base.py:841, in select(condlist, choicelist, default)
#     836     raise TypeError(msg) from None
#     838 # Convert conditions to arrays and broadcast conditions and choices
#     839 # as the shape is needed for the result. Doing it separately optimizes
#     840 # for example when all choices are scalars.
# ...
