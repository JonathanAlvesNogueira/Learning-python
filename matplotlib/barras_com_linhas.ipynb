# %%
import pandas as pd 
import matplotlib.pyplot as plt

dados = {'nome': ['Jonathan', 'carlos', 'pedro']
         ,'bruto':[20,30,50]
         ,'porcentagem' : [20,30,50]}

df = pd.DataFrame(dados)
display(df)
# Out:
#        nome  bruto  porcentagem
# 0  Jonathan     20           20
# 1    carlos     30           30
# 2     pedro     50           50

# %%
import pandas as pd 
import matplotlib.pyplot as plt

dados = {'nome': ['Jonathan', 'Carlos', 'Pedro'],
         'bruto': [20, 30, 50],
         'porcentagem': [20, 30, 50]}

df = pd.DataFrame(dados)
display(df)

fig, ax = plt.subplots()

# Plotar o gráfico de barras com rótulos de dados
bars = ax.bar(df['nome'], df['bruto'])

# Adicionar rótulos de dados acima das barras
for bar in bars:
    # Pega a altura de onde vou querer colocar o rotulo de dados 
    yval = bar.get_height()
    #  Seleciona a posiçãodde onde sera colocado o rotulo 
    ax.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Adicionar uma linha com as porcentagens
ax.plot(df['nome'], df['porcentagem'], color='red', marker='o', label='Porcentagens')

plt.legend()
plt.ylabel('Valores e Porcentagens')
plt.title('Gráfico de Barras com Rótulos de Dados e Linha de Porcentagens')
plt.show()
# Out:
#        nome  bruto  porcentagem
# 0  Jonathan     20           20
# 1    Carlos     30           30
# 2     Pedro     50           50

# %%
fig, ax = plt.subplots()


bars = ax.bar(df['bruto'], df['porcentagem'])

for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

plt.ylabel('Valores')
plt.title('Gráfico de Barras com Rótulos de Dados')
plt.show()

ax.plot(df['bruto'], df['porcentagens'], color='red', marker='o', label='porcentagens')

plt.legend()
plt.ylabel('Valores e Porcentagens')
plt.title('Gráfico de Barras com Rótulos de Dados e Linha de Porcentagens')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\joth1\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'porcentagens'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 14
# ...
