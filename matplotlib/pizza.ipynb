# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
empresas = ['BB', 'Bradesco', 'Nubank', 'Itau', 'Santander']
porcent = [202,103,304,300,100]

none = '%1.1f%%'

explodir = (0,0,0,0.1,0)

# explorar mais as funções, olhar documentação 
plt.pie(porcent, labels=empresas, autopct=none, explode=explodir, shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x10837eb8680>,
# ...
#  [Text(0.8895158924985909, 0.6471178231144894, 'BB'),
#   Text(-0.008562248997809187, 1.0999666758098172, 'Bradesco'),
#   Text(-1.052229628928838, 0.32064436374943533, 'Nubank'),
#   Text(0.01681271823504529, -1.1998822160968756, 'Itau'),
#   Text(1.0471105864348365, -0.3369857857181712, 'Santander')],
#  [Text(0.48519048681741317, 0.3529733580624487, '20.0%'),
#   Text(-0.004670317635168647, 0.5999818231689912, '10.2%'),
#   Text(-0.5739434339611843, 0.17489692568151016, '30.1%'),
#   Text(0.009807418970443084, -0.6999312927231773, '29.7%'),
#   Text(0.5711512289644561, -0.18381042857354793, '9.9%')])
