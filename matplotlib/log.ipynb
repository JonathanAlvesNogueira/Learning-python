# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from time import time

# %%
num = np.arange(10)
indices = np.linspace(0,100000, 10)

plt.figure()

plt.suptitle('SUb title')

plt.subplot(221)
plt.yscale('log')
plt.plot(num, indices, color='r')
