# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
nomes = ['a', 'b', 'c', 'd', 'e']
valores = np.arange(5)
valores2 = [0, 0.5, 1.5,2.5,3.5]

plt.bar(nomes, valores, color='r')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(nomes,valores, color='r')
plt.bar(nomes, valores2, color='k')
# Out:
# <BarContainer object of 5 artists>
