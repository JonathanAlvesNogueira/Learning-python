# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
xa = np.linspace(0,10,5)
cont = np.arange(5)
display(xa)

# cria grafico de linha
plt.plot(xa, cont)
plt.xlabel('Intervalo')
plt.ylabel('Primeiro grafico')
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])
# Text(0, 0.5, 'Primeiro grafico')
