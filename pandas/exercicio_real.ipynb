# %%
import pandas as pd
import numpy as np



url = 'D:/credito.csv'
base_analise_3 = pd.read_csv(url)

display(base_analise_3)
# Out:
#               id  default  idade sexo  dependentes         escolaridade  \
# 0      768805383        0     45    M            3         ensino medio
# 1      818770008        0     49    F            5             mestrado
# 2      713982108        0     51    M            3             mestrado
# 3      769911858        0     40    F            4         ensino medio
# 4      709106358        0     40    M            3  sem educacao formal
# ...          ...      ...    ...  ...          ...                  ...
# 10122  772366833        0     50    M            2             mestrado
# 10123  710638233        1     41    M            2                   na
# 10124  716506083        1     44    F            1         ensino medio
# 10125  717406983        1     30    M            2             mestrado
# 10126  714337233        1     43    F            2             mestrado
#
#       estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# ...

# %%
base_analise_32 = df.copy()
df2 = df2[df2['idade'] > 30]

df2['faixa_idade'] = np.where(df2['idade'] < 40, '30-39 Anos'
                              ,np.where(df2['idade'] < 50, '40-49 Anos'
                              ,np.where(df2['idade'] < 60, '50-59 Anos', '> 60 Anos')))

df2['Faixa_relaionamento'] = np.where(df2['meses_de_relacionamento'] < 10, 'Cliente novo'
                                      ,np.where(df2['meses_de_relacionamento'] < 30, 'Cliente Operavel'
                                      ,np.where(df2['meses_de_relacionamento'] < 50, 'Cliente Senior'
                                      ,'Cliente Premium',)))

df2['faixa_transacoes'] = np.where(df2['qtd_transacoes_12m'] < 20, 'poucas transações'
                                      ,np.where(df2['qtd_transacoes_12m'] < 30, 'transações medias'
                                      ,np.where(df2['qtd_transacoes_12m'] < 50, 'altas transações'
                                      ,'Muitas transações',)))

df2['faixa_qtd_produtos'] = np.where(df2['qtd_produtos'] <= 2, '1-2 produtos'
                                      ,np.where(df2['qtd_produtos'] <= 5, '3-5 produtos'
                                     , '> 6 produtos'))
                                    

display(df2)
# Out:
#               id  default  idade sexo  dependentes         escolaridade  \
# 0      768805383        0     45    M            3         ensino medio
# 1      818770008        0     49    F            5             mestrado
# 2      713982108        0     51    M            3             mestrado
# 3      769911858        0     40    F            4         ensino medio
# 4      709106358        0     40    M            3  sem educacao formal
# ...          ...      ...    ...  ...          ...                  ...
# 10121  713899383        0     56    F            1             mestrado
# 10122  772366833        0     50    M            2             mestrado
# 10123  710638233        1     41    M            2                   na
# 10124  716506083        1     44    F            1         ensino medio
# 10126  714337233        1     43    F            2             mestrado
#
#       estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# ...

# %%
base_analise_3 = df2.copy()

base_analise_3['qtd_produtos'] = df2['qtd_produtos']


table = pd.pivot_table(base_analise_3, columns='faixa_idade', values='qtd_produtos', 
                       fill_value='-', aggfunc='sum', index=['Faixa_relaionamento'])


TB_analise_transacoes = pd.pivot_table(base_analise_3, columns='Faixa_relaionamento', index='faixa_transacoes', aggfunc='size', fill_value='-')

TB_analise_transacoes.loc['Total', :] = TB_analise_transacoes.sum()
TB_analise_transacoes['Total'] = TB_analise_transacoes.sum(axis=1)


display(soma)

# porcentagens = TB_analise_transacoes.div(TB_analise_transacoes['Total'], axis=0) * 100
# display(porcentagens)


display(table)
print('----------------------------------------------------------------------------------------------------------')
display(TB_analise_transacoes)
# Out:
# 99
# faixa_idade         30-39 Anos 40-49 Anos  50-59 Anos > 60 Anos
# Faixa_relaionamento
# Cliente Operavel          4243       2386          41         -
# Cliente Premium              -          -         757      1285
# Cliente Senior            2762      14687       10529       863
# ----------------------------------------------------------------------------------------------------------
# Faixa_relaionamento  Cliente Operavel  Cliente Premium  Cliente Senior   Total
# faixa_transacoes
# Muitas transações              1214.0            292.0          5413.0  6919.0
# altas transações                443.0            167.0          1728.0  2338.0
# poucas transações                14.0             13.0            73.0   100.0
# transações medias                49.0             42.0           414.0   505.0
# Total                          1720.0            514.0          7628.0  9862.0

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 cubo = base_analise_3.groupby('escolaridade')['Faixa_relacionamento'].size
#       2 display(cubo)
#
# File c:\Users\joth1\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\generic.py:1961, in DataFrameGroupBy.__getitem__(self, key)
#    1954 if isinstance(key, tuple) and len(key) > 1:
#    1955     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1956     # valid syntax, so don't raise
#    1957     raise ValueError(
#    1958         "Cannot subset columns with a tuple with more than one element. "
#    1959         "Use a list instead."
#    1960     )
# -> 1961 return super().__getitem__(key)
#
# File c:\Users\joth1\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
# ...
