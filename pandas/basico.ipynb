# %%
import pandas as pd
caminho = 'C:/Users/joth1/Downloads/FootballStadiums.csv'

dt = pd.read_csv(caminho)
display(dt)
# Out:
#      Confederation                   Stadium         City  \
# 0             UEFA       Stadiumi Besëlidhja        Lezhë
# 1             UEFA       Stadiumi Flamurtari        Vlorë
# 2             UEFA             Stadiumi Laçi         Laçi
# 3             UEFA      Stadiumi Niko Dovana       Durrës
# 4             UEFA  Stadiumi Selman Stërmasi       Tirana
# ...            ...                       ...          ...
# 2019          UEFA           Liberty Stadium      Swansea
# 2020          UEFA           Parc y Scarlets     Llanelli
# 2021          UEFA               Park Avenue  Aberystwyth
# 2022          UEFA      Principality Stadium      Cardiff
# 2023          UEFA         Racecourse Ground      Wrexham
#
#                          HomeTeams  Capacity  Country  IOC  Population
# 0                       Besëlidhja      7000  Albania  ALB     2876591
# 1                 Flamurtari Vlorë      8200  Albania  ALB     2876591
# ...

# %%
dados = dt.head(10)
display(dados)
dados.group
# Out:
#   Confederation                      Stadium       City  \
# 0          UEFA          Stadiumi Besëlidhja      Lezhë
# 1          UEFA          Stadiumi Flamurtari      Vlorë
# 2          UEFA                Stadiumi Laçi       Laçi
# 3          UEFA         Stadiumi Niko Dovana     Durrës
# 4          UEFA     Stadiumi Selman Stërmasi     Tirana
# 5          UEFA          Stadiumi Skënderbeu      Korçë
# 6           CAF      Stade 1er Novembre 1954  Tizi Ouzu
# 7           CAF           Stade Ahmed Zabana       Oran
# 8           CAF           Stade Amar Hareche   El Eulma
# 9           CAF  Stade de l'Unité Maghrébine     Béjaïa
#
#                       HomeTeams  Capacity  Country  IOC  Population
# 0                    Besëlidhja      7000  Albania  ALB     2876591
# 1              Flamurtari Vlorë      8200  Albania  ALB     2876591
# 2                       KF Laçi      5000  Albania  ALB     2876591
# 3                         Teuta     12040  Albania  ALB     2876591
# ...

# %%
agrupamento = dt.groupby('Confederation')
agrupamento = agrupamento.count()
display(agrupamento)
# Out:
#                Stadium  City  HomeTeams  Capacity  Country   IOC  Population
# Confederation
# AFC                252   252        252       252      252   252         252
# CAF                 91    91         91        91       91    91          91
# CONCACAF           190   190        190       190      190   190         190
# CONMEBOL           124   124        124       124      124   124         124
# OFC                  3     3          3         3        3     3           3
# UEFA              1364  1364       1364      1364     1364  1364        1364
