# %%
import pandas as pd
import numpy as np

url = 'D:/donwloads/horarios_1.xlsx'

dt = pd.read_excel(url)
display(dt)
# Out:
#                      cnpj                                       razao_social  \
# 0      34.805.903/0001-61                      AMATUR AMAZÔNIA TURISMO LTDA.
# 1      34.805.903/0001-61                      AMATUR AMAZÔNIA TURISMO LTDA.
# 2      34.805.903/0001-61                      AMATUR AMAZÔNIA TURISMO LTDA.
# 3      34.805.903/0001-61                      AMATUR AMAZÔNIA TURISMO LTDA.
# 4      34.805.903/0001-61                      AMATUR AMAZÔNIA TURISMO LTDA.
# ...                   ...                                                ...
# 10991  18.538.045/0001-80  VTR TRANSPORTE RODOVIARIO DE PASSAGEIROS LTDA ...
# 10992  18.538.045/0001-80  VTR TRANSPORTE RODOVIARIO DE PASSAGEIROS LTDA ...
# 10993  18.538.045/0001-80  VTR TRANSPORTE RODOVIARIO DE PASSAGEIROS LTDA ...
# 10994  18.538.045/0001-80  VTR TRANSPORTE RODOVIARIO DE PASSAGEIROS LTDA ...
# 10995  18.538.045/0001-80  VTR TRANSPORTE RODOVIARIO DE PASSAGEIROS LTDA ...
#
# ...

# %%
display(dt.columns)
display(dt.dtypes)
# Out:
# Index(['cnpj', 'razao_social', 'data_autorizacao', 'prefixo',
#        'descricao_linha', 'tipo_veiculo', 'sentido', 'horario',
#        'segunda_feira', 'terca_feira', 'quarta_feira', 'quinta_feira',
#        'sexta_feira', 'sabado', 'domingo', 'janeiro', 'fevereiro', 'marco',
#        'abril', 'maio', 'junho', 'julho', 'agosto', 'setembro', 'outubro',
#        'novembro', 'dezembro'],
#       dtype='object')
# cnpj                        object
# razao_social                object
# data_autorizacao    datetime64[ns]
# prefixo                     object
# descricao_linha             object
# tipo_veiculo                object
# sentido                     object
# horario                     object
# segunda_feira               object
# terca_feira                 object
# quarta_feira                object
# quinta_feira                object
# sexta_feira                 object
# sabado                      object
# domingo                     object
# ...

# %%
display(dt['horario'][1])
# Out:
# datetime.time(18, 30)
