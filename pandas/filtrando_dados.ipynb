# %%
import pandas as pd
import numpy as np

url = 'D:/credito.csv'
df = pd.read_csv(url)
display(df)
# Out:
#               id  default  idade sexo  dependentes         escolaridade  \
# 0      768805383        0     45    M            3         ensino medio
# 1      818770008        0     49    F            5             mestrado
# 2      713982108        0     51    M            3             mestrado
# 3      769911858        0     40    F            4         ensino medio
# 4      709106358        0     40    M            3  sem educacao formal
# ...          ...      ...    ...  ...          ...                  ...
# 10122  772366833        0     50    M            2             mestrado
# 10123  710638233        1     41    M            2                   na
# 10124  716506083        1     44    F            1         ensino medio
# 10125  717406983        1     30    M            2             mestrado
# 10126  714337233        1     43    F            2             mestrado
#
#       estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# ...

# %%
idade_maior = df['idade'] > 60
display(df[idade_maior])

## ou 
idade_20 = df.query('idade < 40')
display(idade_20)

df.join
# Out:
#               id  default  idade sexo  dependentes         escolaridade  \
# 11     710821833        0     65    M            1                   na
# 18     806160108        0     61    M            1         ensino medio
# 21     708508758        1     62    F            0             mestrado
# 27     804424383        0     63    M            1                   na
# 39     708300483        1     66    F            0            doutorado
# ...          ...      ...    ...  ...          ...                  ...
# 9624   715600533        0     61    M            0             mestrado
# 9734   716816583        0     61    M            0             mestrado
# 9853   713315433        0     61    M            2  sem educacao formal
# 9980   711788583        0     61    F            1             mestrado
# 10107  713924283        1     61    M            0             mestrado
#
#       estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# ...

# %%
df['sexo'].value_counts()
# Out:
# sexo
# F    5358
# M    4769
# Name: count, dtype: int64
