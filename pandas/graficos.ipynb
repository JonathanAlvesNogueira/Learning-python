# %%
# plot.bar:
# Objetivo: Gráficos de barras.
# Uso: df.plot.bar(x='Categoria', y='Valores').


# plot.scatter:
# Objetivo: Gráficos de dispersão.
# Uso: df.plot.scatter(x='X', y='Y').


# plot.pie:
# Objetivo: Gráficos de pizza.
# Uso: df.plot.pie(y='Valores', autopct='%1.1f%%', startangle=90).

import pandas as pd
import numpy as np 


dt = pd.DataFrame({
    'lista' : np.arange(8)**2,
    'lista2': np.arange(8),
    'lista3' : np.arange(8) + 2
})

display(dt)
display(dt.plot(x='lista2', y='lista'))
# Out:
#    lista  lista2  lista3
# 0      0       0       2
# 1      1       1       3
# 2      4       2       4
# 3      9       3       5
# 4     16       4       6
# 5     25       5       7
# 6     36       6       8
# 7     49       7       9
# <Axes: xlabel='lista2'>

# %%
display(dt.plot.bar(x='lista', y='lista2'))
# Out:
# <Axes: xlabel='lista'>

# %%
display(dt.plot.pie(y='lista'))
# Out:
# <Axes: ylabel='lista'>

# %%
url = 'D:/donwloads/archive/player_data.csv'

dt = pd.read_csv(url)
display(dt.columns)
dt.plot.scatter(x='year_start', y='weight')
# Out:
# Index(['name', 'year_start', 'year_end', 'position', 'height', 'weight',
#        'birth_date', 'college'],
#       dtype='object')
# <Axes: xlabel='year_start', ylabel='weight'>
